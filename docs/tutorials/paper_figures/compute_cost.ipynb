# %% [markdown]
# # Supplementary Table 2: full-model compute cost
#
# Load the packaged measurements, apply manuscript units, and save the table.

# %% [markdown]
# ## Reproduction route: files passed between analysis steps
#
# Read the steps from top to bottom. Each one names the code that runs, the files
# it reads, the files it writes, and the next command that consumes those files.
# Steps marked `manuscript result bundle` record the files used for the paper;
# public steps can be run from this checkout.

# %% [markdown]
# ### Step 1: measure each manuscript full-model run
#
# **Paper:** Supplementary Table 2
#
# ```text
# six-stage training pipeline with timing and memory instrumentation
# ```
#
# **Reads:** `one manuscript model configuration and aligned H5AD per dataset`
#
# **Writes:** `training_run_summary.json with elapsed seconds, peak host RSS and peak PyTorch allocation`
#
# **Next:** `collect five rows`
#
# **Availability:** public

# %% [markdown]
# ### Step 2: collect and validate
#
# **Paper:** Supplementary Table 2
#
# ```text
# python -m scripts.results.build_full_model_compute_cost_table --results-dir <compute-cost-results> --output-dir <formatted-table-run>
# ```
#
# **Reads:** `five manuscript training_run_summary.json files`
#
# **Writes:** `full_model_compute_cost.csv and source-value audit`
#
# **Next:** `format table`
#
# **Availability:** public

# %% [markdown]
# ### Step 3: format released table
#
# **Paper:** Supplementary Table 2
#
# ```text
# format_full_model_compute_cost()
# ```
#
# **Reads:** `full_model_compute_cost.csv`
#
# **Writes:** `full_model_compute_cost_formatted.csv/.md`
#
# **Next:** `copy values to the TeX-native table`
#
# **Availability:** public

# %% [markdown]
# ## Load figure inputs

# %%
import pandas as pd

pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_columns", None)

from pathlib import Path

from IPython.display import display

from CytoBridge.results.compute_cost import (
    format_full_model_compute_cost,
    load_full_model_compute_cost,
    write_full_model_compute_cost_tables,
)

results = load_full_model_compute_cost()
display(results.measurements)
# Out:
#          dataset  time_points_used_for_training  training_time_point_labels  \
# 0        admouse                              3       2.5, 5.7, 17.9 months
# 1         arista                              5        2, 5, 10, 15, 20 DPI
# 2  chicken_heart                              4            D4, D7, D10, D14
# 3          mosta                              4  E12.5, E13.5, E14.5, E15.5
# 4      zebrafish                              5    5.25, 10, 12, 18, 24 hpf
#
#    observed_cells_or_spots  training_time_seconds  peak_host_memory_mib  \
# 0                   172092             696.454413           2446.660156
# 1                    46199            1324.537501           9262.132812
# 2                     3550             761.157402           2833.042969
# 3                   344603            1997.504037          17023.750000
# 4                    11999            1239.225866           2174.132812
#
#    peak_gpu_allocation_mib
# 0               708.554199
# ...

# %% [markdown]
# ## Format
#
# Convert seconds to minutes and MiB to GiB.

# %%
table = format_full_model_compute_cost(results)
display(table)
# Out:
#          Dataset  Time points used for training Observed cells/spots  \
# 0       AD mouse       3: 2.5, 5.7, 17.9 months              172,092
# 1         ARISTA        5: 2, 5, 10, 15, 20 DPI               46,199
# 2  Chicken heart            4: D4, D7, D10, D14                3,550
# 3          MOSTA  4: E12.5, E13.5, E14.5, E15.5              344,603
# 4      Zebrafish    5: 5.25, 10, 12, 18, 24 hpf               11,999
#
#   Training time (min) Peak host memory (GiB) Peak GPU allocation (GiB)
# 0                11.6                   2.39                      0.69
# 1                22.1                   9.05                      0.85
# 2                12.7                   2.77                      1.88
# 3                33.3                  16.62                      1.03
# 4                20.7                   2.12                      0.56

# %% [markdown]
# ## Save and check

# %%
output_dir = Path("outputs") / "full_model_compute_cost_notebook"
paths = write_full_model_compute_cost_tables(results, output_dir)
{name: {"file": path.name, "written": path.is_file()} for name, path in paths.items()}
# Out:
# {'raw': {'file': 'full_model_compute_cost.csv', 'written': True},
#  'display': {'file': 'full_model_compute_cost_table.csv', 'written': True},
#  'markdown': {'file': 'full_model_compute_cost_table.md', 'written': True}}

# %% [markdown]
# The same calculation is available from the command line:
#
# ```bash
# python scripts/results/build_full_model_compute_cost_table.py --output-dir outputs/full_model_compute_cost
# ```
